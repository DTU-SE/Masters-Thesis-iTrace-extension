# %%
import MySQLdb
import pandas

# %%
db = MySQLdb.connect(host="localhost",
                     user="root",
                     passwd="1234",
                     db="iTrace")

# %%
cursor = db.cursor()
cursor.execute("SELECT * FROM session_info")
# Out:
# 1L

# %%
dataframe = pandas.read_sql("SELECT * FROM gazes", db)

# %%
#print dataframe.loc[0]
print dataframe
# Out:
#                      name  type            gaze_session_id    x    y  \
# 0    TestNestedLoops.java  java  20171017T110349-0343+0200  452  350
# 1    TestNestedLoops.java  java  20171017T110349-0343+0200  463  318
# 2    TestNestedLoops.java  java  20171017T110349-0343+0200  468  298
# 3    TestNestedLoops.java  java  20171017T110349-0343+0200  468  297
# 4    TestNestedLoops.java  java  20171017T110349-0343+0200  468  298
# 5    TestNestedLoops.java  java  20171017T110349-0343+0200  469  298
# 6    TestNestedLoops.java  java  20171017T110349-0343+0200  470  298
# 7    TestNestedLoops.java  java  20171017T110349-0343+0200  470  297
# 8    TestNestedLoops.java  java  20171017T110349-0343+0200  471  297
# 9    TestNestedLoops.java  java  20171017T110349-0343+0200  476  297
# 10   TestNestedLoops.java  java  20171017T110349-0343+0200  481  298
# 11   TestNestedLoops.java  java  20171017T110349-0343+0200  485  297
# 12   TestNestedLoops.java  java  20171017T110349-0343+0200  488  296
# ...
