# %%
import iTraceAnalyser_backup as IA

# %%
#Creating session fixation data for a specific user at different sensitivities. For Chapter 4 section 1.

rawGazes = IA.get_raw_gazes("localhost","root","1234","iTrace",'20171219T095731-0417+0100')
fixations15 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171219T095731-0417+0100', 5)
fixations25 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171219T095731-0417+0100',10)
fixations35 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171219T095731-0417+0100',15)
fixations45 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171219T095731-0417+0100',20)
fixations55 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171219T095731-0417+0100',25)
fixations65 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171219T095731-0417+0100',30)

#Creating scatter plots for the fixation sesnsitivity analysis Chapter 4 section 1.
IA.gaze_scatter_plot(rawGazes, "TestGaze", "Gazes")
IA.fixation_scatter_plot(fixations15,"TestFix5", "Fixations 5")
IA.fixation_scatter_plot(fixations25,"TestFix10", "Fixations 10")
IA.fixation_scatter_plot(fixations35,"TestFix15", "Fixations 15")
IA.fixation_scatter_plot(fixations45,"TestFix20", "Fixations 20")
IA.fixation_scatter_plot(fixations55,"TestFix25", "Fixations 25")
IA.fixation_scatter_plot(fixations65,"TestFix30", "Fixations 30")

# %%
#Importing the test subjects data
iTrace1 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171201T092946-0684+0100',15) 
iTrace2 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171201T101056-0578+0100',15) 
iTrace3 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171205T100741-0299+0100',15) 
iTrace4 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171205T102737-0035+0100',15) 
iTrace5 = IA.get_session_dispersion("localhost","root","1234","iTrace",'20171205T105857-0765+0100',15) 

#print IA.session_duration(iTrace1)

# %%
iTrace1B = IA.get_session("localhost","root","1234","iTrace",'20171201T092946-0684+0100',450) 
print len(iTrace1), len(iTrace1B)

avg1 = 0
bavg = 0
for i in iTrace1:
    avg1 += i['duration']
for i in iTrace1B:
    bavg += i['duration']

print avg1/len(iTrace1), bavg/len(iTrace1B)
# Out:
# 528 256
# 0.217825832962 0.731938298023

# %%
max_dur = 0
count = 0
for i in  iTrace1:
    print "dur " + str(i['duration'])
    count += 1
    if i['duration'] > max_dur:
        max_dur = i['duration']
print count
print max_dur

#Creating process mining data, for Chapter 4 section 3
IA.process_mining_data([iTrace1,iTrace2,iTrace3,iTrace4,iTrace5],"test_sort_lines_dispersion.csv",'lines')
IA.process_mining_data([iTrace1,iTrace2,iTrace3,iTrace4,iTrace5],"test_sort_userdef_dispersion.csv",'user_defined',"insertion.csv")
# Out:
# dur 0.243380689
# dur 0.178129811
# dur 0.199625161
# dur 0.122359386
# dur 0.145120491
# dur 0.288522194
# dur 0.189010903
# dur 0.121969397
# dur 0.133214088
# dur 0.421513921
# dur 0.192745124
# dur 0.177302427
# dur 0.166447236
# dur 0.110573206
# dur 0.14367929
# dur 0.144448029
# dur 0.209959388
# dur 0.288623357
# dur 0.111685018
# dur 0.277014578
# dur 0.11156675
# dur 0.128648086
# dur 0.288698619
# dur 0.209931043
# dur 0.178380029
# dur 0.100034699
# dur 0.111211947
# dur 0.288458662
# dur 0.243645569
# dur 0.110725684
# dur 0.244177284
# dur 0.244310212
# dur 0.299888574
# dur 0.17709717
# dur 0.111144017
# dur 0.221860904
# dur 0.243822482
# dur 0.233203825
# dur 0.455375548
# dur 0.100240444
# dur 0.333441338
# dur 0.188933687
# dur 0.195776093
# dur 0.100077704
# dur 0.11028389
# dur 0.266623172
# dur 0.16654058
# dur 0.266813279
# dur 0.110994473
# dur 0.221836957
# dur 0.133206269
# dur 0.254617073
# dur 0.110754517
# dur 0.111075109
# dur 0.21619824
# ...

# %%
#Creating bar plots for Chapter 4 section 2.
IA.fixation_count_bar(iTrace1,"count_lines","line")
IA.fixation_count_bar(iTrace1,"count_types","sce_type")

IA.fixation_duration_bar(iTrace1,"dur_lines","line")
IA.fixation_duration_bar(iTrace1,"dur_types","sce_type")

IA.fixation_average_duration_bar(iTrace1,"avg_dur_lines","line")
IA.fixation_average_duration_bar(iTrace1,"avg_dur_types","sce_type")

IA.fixation_max_duration_bar(iTrace1,"dur_max_lines","line")
IA.fixation_max_duration_bar(iTrace1,"dur_max_types","sce_type")



#IA.fixation_count_bar(iTrace5,"NON_count_lines","line")
#IA.fixation_count_bar(iTrace5,"NON_count_types","sce_type")

#IA.fixation_duration_bar(iTrace5,"NON_dur_lines","line")
#IA.fixation_duration_bar(iTrace5,"NON_dur_types","sce_type")

#IA.fixation_average_duration_bar(iTrace5,"NON_avg_dur_lines","line")
#IA.fixation_average_duration_bar(iTrace5,"NON_avg_dur_types","sce_type")
# Out:
# [40L, 41L, 43L, 44L, 46L, 47L, 49L, 51L, 55L, 56L, 58L, 59L, 60L, 61L, 62L, 64L, 65L, 67L, 71L, 72L, 73L, 74L, 76L, 82L, 86L, 87L, 88L, 90L, 92L, 93L, 94L, 96L, 103L, 106L, 107L, 109L, 114L, 120L, 121L, 123L, 125L, 126L, 129L, 130L, 134L, 141L, 142L, 143L, 145L, 146L, 147L, 151L, 152L, 155L, 156L, 157L, 162L, 163L, 164L, 169L, 172L, 173L, 176L, 177L, 178L, 183L, 187L, 194L, 196L, 197L, 203L, 206L, 208L, 209L, 210L, 211L]
# ['COMMENT', 'FORSTATEMENT', 'METHOD', 'TYPE', 'VARIABLE']
